# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('series.csv')
df.head()
# Out:
#    Unnamed: 0   show_id     type                             title  \
# 0           2  70234439  TV Show                Transformers Prime
# 1           3  80058654  TV Show  Transformers: Robots in Disguise
# 2           5  80163890  TV Show                           Apaches
# 3           8  80117902  TV Show                      Fire Chasers
# 4          26  80244601  TV Show                   Castle of Stars
#
#                                                 cast        country  \
# 0  Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# 1  Will Friedle, Darren Criss, Constance Zimmer, ...  United States
# 2  Alberto Ammann, Eloy Azorín, Verónica Echegui,...          Spain
# 3                                                NaN  United States
# 4  Chaiyapol Pupart, Jintanutda Lummakanon, Worra...            NaN
#
#           date_added  release_year    rating  duration  \
# 0  September 8, 2018          2013  TV-Y7-FV         1
# 1  September 8, 2018          2016     TV-Y7         1
# 2  September 8, 2017          2016     TV-MA         1
# 3  September 8, 2017          2017     TV-MA         1
# 4  September 7, 2018          2015     TV-14         1
#
#                                            listed_in  \
# 0                                           Kids' TV
# 1                                           Kids' TV
# 2  Crime TV Shows, International TV Shows, Spanis...
# 3                    Docuseries, Science & Nature TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  With the help of three human allies, the Autob...
# 1  When a prison ship crash unleashes hundreds of...
# 2  A young journalist is forced into a life of cr...
# 3  As California's 2016 fire season rages, brave ...
# 4  As four couples with different lifestyles go t...

# %%
df.fillna('')
# Out:
#       Unnamed: 0   show_id     type  \
# 0              2  70234439  TV Show
# 1              3  80058654  TV Show
# 2              5  80163890  TV Show
# 3              8  80117902  TV Show
# 4             26  80244601  TV Show
# ...          ...       ...      ...
# 1964        6228  80159925  TV Show
# 1965        6229  80000063  TV Show
# 1966        6230  70286564  TV Show
# 1967        6232  70281022  TV Show
# 1968        6233  70153404  TV Show
#
#                                             title  \
# 0                              Transformers Prime
# 1                Transformers: Robots in Disguise
# 2                                         Apaches
# 3                                    Fire Chasers
# 4                                 Castle of Stars
# ...                                           ...
# 1964                                     Kikoriki
# 1965                                 Red vs. Blue
# 1966                                        Maron
# 1967  A Young Doctor's Notebook and Other Stories
# 1968                                      Friends
#
#                                                    cast         country  \
# 0     Peter Cullen, Sumalee Montano, Frank Welker, J...   United States
# 1     Will Friedle, Darren Criss, Constance Zimmer, ...   United States
# 2     Alberto Ammann, Eloy Azorín, Verónica Echegui,...           Spain
# 3                                                         United States
# 4     Chaiyapol Pupart, Jintanutda Lummakanon, Worra...
# ...                                                 ...             ...
# 1964                                      Igor Dmitriev
# 1965  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 1966  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 1967  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 1968  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#              date_added  release_year    rating  duration  \
# 0     September 8, 2018          2013  TV-Y7-FV         1
# 1     September 8, 2018          2016     TV-Y7         1
# 2     September 8, 2017          2016     TV-MA         1
# 3     September 8, 2017          2017     TV-MA         1
# 4     September 7, 2018          2015     TV-14         1
# ...                 ...           ...       ...       ...
# 1964                             2010      TV-Y         2
# 1965                             2015        NR        13
# 1966                             2016     TV-MA         4
# 1967                             2013     TV-MA         2
# 1968                             2003     TV-14        10
#
#                                               listed_in  \
# 0                                              Kids' TV
# 1                                              Kids' TV
# 2     Crime TV Shows, International TV Shows, Spanis...
# 3                       Docuseries, Science & Nature TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 1964                                           Kids' TV
# 1965  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 1966                                        TV Comedies
# 1967           British TV Shows, TV Comedies, TV Dramas
# 1968                     Classic & Cult TV, TV Comedies
#
#                                             description
# 0     With the help of three human allies, the Autob...
# 1     When a prison ship crash unleashes hundreds of...
# 2     A young journalist is forced into a life of cr...
# 3     As California's 2016 fire season rages, brave ...
# 4     As four couples with different lifestyles go t...
# ...                                                 ...
# 1964  A wacky rabbit and his gang of animal pals hav...
# 1965  This parody of first-person shooter games, mil...
# 1966  Marc Maron stars as Marc Maron, who interviews...
# 1967  Set during the Russian Revolution, this comic ...
# 1968  This hit sitcom follows the merry misadventure...
#
# [1969 rows x 12 columns]

# %%
# Required columns - Title and movie plot
content = df[["title","cast","listed_in" "description"]]           
content = content.set_index('title')

# %%
import nltk 
nltk.download('punkt') 
nltk.download('averaged_perceptron_tagger') 
nltk.download('wordnet') 
  
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 
  
from nltk.corpus import stopwords 
nltk.download('stopwords') 
stop_words = set(stopwords.words('english')) 
  
VERB_CODES = {'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'}
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Anda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Anda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Anda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_sentences(text): 
    text = text.lower() 
    temp_sent =[] 
    words = nltk.word_tokenize(text) 
    tags = nltk.pos_tag(words) 
    for i, word in enumerate(words): 
        if tags[i][1] in VERB_CODES:  
            lemmatized = lemmatizer.lemmatize(word, 'v') 
        else: 
            lemmatized = lemmatizer.lemmatize(word) 
        if lemmatized not in stop_words and lemmatized.isalpha(): 
            temp_sent.append(lemmatized) 
          
    description = ' '.join(temp_sent) 
    description = description.replace("n't", " not") 
    description = description.replace("'m", " am") 
    description = description.replace("'s", " is") 
    description = description.replace("'re", " are") 
    description = description.replace("'ll", " will") 
    description = description.replace("'ve", " have") 
    description = description.replace("'d", " would") 
    return description 
  
content["plot"]= content["description"].apply(preprocess_sentences) 
content.head()
# Out:
#                                                                         description  \
# title
# Transformers Prime                With the help of three human allies, the Autob...
# Transformers: Robots in Disguise  When a prison ship crash unleashes hundreds of...
# Apaches                           A young journalist is forced into a life of cr...
# Fire Chasers                      As California's 2016 fire season rages, brave ...
# Castle of Stars                   As four couples with different lifestyles go t...
#
#                                                                                plot
# title
# Transformers Prime                help three human ally autobots protect earth o...
# Transformers: Robots in Disguise  prison ship crash unleashes hundred decepticon...
# Apaches                           young journalist force life crime save father ...
# Fire Chasers                      california fire season rage brave backcountry ...
# Castle of Stars                   four couple different lifestyle go ebb flow jo...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
  
# Vectorizing pre-processed movie plots using TF-IDF 
tfidfvec = TfidfVectorizer() 
tfidf_movieid = tfidfvec.fit_transform((content["plot"])) 
  
# Finding cosine similarity between vectors 
from sklearn.metrics.pairwise import cosine_similarity 
cos_sim = cosine_similarity(tfidf_movieid, tfidf_movieid)

# %%
# Storing indices of the data 
indices = pd.Series(content.index) 
  
def recommendations(title, cosine_sim = cos_sim): 
    recommended_movies = [] 
    index = indices[indices == title].index[0] 
    similarity_scores = pd.Series(cosine_sim[index]).sort_values(ascending = False) 
    top_10_movies = list(similarity_scores.iloc[1:11].index) 
    for i in top_10_movies: 
        recommended_movies.append(list(content.index)[i]) 
    return recommended_movies

# %%
recommendations("Suits")
# Out:
# ['How to Get Away with Murder',
#  'Dandy',
#  'This Is My Love',
#  'Persona',
#  'Black Earth Rising',
#  'The Family Court',
#  'Tabula Rasa',
#  '마녀사냥',
#  'Yes We Can!',
#  'Memory Love']

# %%
recommendations("Surviving R. Kelly")
# Out:
# ['Examination of Conscience',
#  'I AM A KILLER',
#  'The Disappearance of Madeleine McCann',
#  'Age of Tanks',
#  'Club Friday The Series 6',
#  'Origins Collection',
#  'The L Word',
#  'The War: A Film by Ken Burns and Lynn Novick',
#  "Oliver Stone's Untold History of the United States",
#  'Classic Legends']

# %%
sorted(list(df.title.unique()))[1000:]
# Out:
# ['Medal of Honor',
#  'Medical Police',
#  'Medici: Masters of Florence',
#  'Meet the Adebanjos',
#  'Mega Food',
#  'MegaTruckers',
#  'Melodies of Life - Born This Way',
#  'Memories of the Alhambra',
#  'Memory Love',
#  'Men on a Mission',
#  'Mere Papa Hero Hiralal',
#  'Merlin',
#  'Merlí',
#  'Merry Happy Whatever',
#  'Messiah',
#  'Metallica: Some Kind of Monster',
#  'Meteor Garden',
#  'Mexico Diseña',
#  'Mia and Me',
#  'Midnight Diner: Tokyo Stories',
#  'Midnight Misadventures With Mallika Dua',
#  'Mighty Little Bheem',
#  'Mighty Little Bheem: Diwali',
#  'Mighty Morphin Alien Rangers',
#  'Mighty Morphin Power Rangers',
#  'Millennials',
#  'Million Pound Menu',
#  'Million Yen Women',
#  'Mind Game',
#  'Minecraft: Story Mode',
#  'Mini Wolf',
#  'Miniforce',
#  'Miniforce X',
#  'Minute to Win It',
#  'Miraculous: Tales of Ladybug & Cat Noir',
#  'Misaeng',
#  'Miss Culinary',
#  'Miss Dynamite',
#  'Miss Panda & Mr. Hedgehog',
#  'Miss Rose',
#  'Miss in Kiss',
#  'Mob Psycho 100',
#  'Mobile Suit Gundam UC',
#  'Mobile Suit Gundam: Iron-Blooded Orphans',
#  'Molang',
#  'Momo Salon',
#  'Monarca',
#  'Money for Nothing',
#  'Monkey Planet',
#  'Monkey Twins',
#  "Monty Don's French Gardens",
#  "Monty Don's Italian Gardens",
#  'Monty Python Best Bits (mostly)',
#  "Monty Python's Almost the Truth",
#  "Monty Python's Fliegender Zirkus",
#  "Monty Python's Flying Circus",
#  "Monty Python's Personal Best",
#  'Monzón: A Knockout Blow',
#  'More to Say',
#  'Morphle',
#  'Mortel',
#  'Mossad 101',
#  'Most Beautiful Thing',
#  'Mother Goose Club',
#  'Motown Magic',
#  'Moving Art',
#  'Moving On',
#  'Mr. Iglesias',
#  'Mr. Sunshine',
#  'Mr. Young',
#  'Murder Maps',
#  'Murder Mountain',
#  'Murderous Affairs',
#  "Murphy's Law of Love",
#  'Mutant Busters',
#  "My Babysitter's a Vampire",
#  'My Country: The New Age',
#  'My Dear Boy',
#  'My Dear Warrior',
#  'My First First Love',
#  'My Hotter Half',
#  "My Husband Won't Fit",
#  'My Life My Story',
#  'My Little Baby',
#  'My Little Pony: Friendship Is Magic',
#  'My MVP Valentine',
#  'My Next Guest Needs No Introduction With David Letterman',
#  'My Only Love Song',
#  'My Pride',
#  'My Runway',
#  'My Sassy Girl',
#  'My Tattoo Addiction',
#  'Mystery Science Theater 3000',
#  'Mystery Science Theater 3000: The Return',
#  'Mystic Whispers',
#  'Mythomaniac',
#  'Myths & Monsters',
#  'NATURE: Natural Born Hustlers',
#  'NCIS',
#  'NSU German History X',
#  'Nailed It',
#  'Nailed It! France',
#  'Nailed It! Germany',
#  'Nailed It! Holiday!',
#  'Nailed It! Mexico',
#  'Nailed It! Spain',
#  'Narcos',
#  'Narcos: Mexico',
#  'Narcoworld: Dope Stories',
#  'Naruto',
#  "Nature's Great Events (2009)",
#  "Nature's Great Events: Diaries",
#  "Nature's Great Race",
#  "Nature's Weirdest Events",
#  'Nature: Animals With Cameras',
#  'Nazi Mega Weapons',
#  'Neo Yokio',
#  'Neon Genesis Evangelion',
#  'Netflix Presents: The Characters',
#  'New Girl',
#  'Nightflyers',
#  'Nightmare High',
#  'Nightmare Tenants, Slum Landlords',
#  'Ninja Hattori',
#  'Ninja Turtles: The Next Mutation',
#  'Nisman: The Prosecutor, the President, and the Spy',
#  'No Good Nick',
#  'No Time for Shame',
#  'No Tomorrow',
#  'Nobel',
#  "Nobody's Looking",
#  'Noddy Toyland Detective',
#  'Norm Macdonald Has a Show',
#  'Norsemen',
#  'North & South',
#  'Northern Rescue',
#  'November 13: Attack on Paris',
#  'Nowhere Man',
#  'Nuestra Lucha Libre',
#  'Nura: Rise of the Yokai Clan: Demon Capital',
#  'Nurse Jackie',
#  'Nurses Who Kill',
#  'O-Negative, Love Can’t Be Designed',
#  'OCTB',
#  'Occupied',
#  'Octonauts',
#  'Oddbods',
#  'Off Camera',
#  'Office Girls',
#  'Offspring',
#  'Oggy and the Cockroaches',
#  'Oh My Ghost',
#  "Oh No! It's an Alien Invasion",
#  'Old Money',
#  "Oliver Stone's Untold History of the United States",
#  'Ollie & Moon',
#  'On Children',
#  'On My Block',
#  'Once Upon A Time In Lingjian Mountain',
#  'Once Upon a Time',
#  'One Day at a Time',
#  'One More Time',
#  'One Spring Night',
#  'One Strange Rock',
#  'One-Punch Man',
#  'Operation Gold Rush',
#  'Operation Proposal',
#  'Orange Is the New Black',
#  'Ordinary Heroes',
#  'Origins Collection',
#  "Oscar's Oasis",
#  'Osmosis',
#  'Our Planet',
#  'Ouran High School Host Club',
#  'Outback Truckers',
#  'Outlander',
#  'Ozark',
#  'P. King Duckling',
#  'PILI Fantasy: War of Dragons',
#  'PJ Masks',
#  'Paap-O-Meter',
#  'Pablo',
#  'Pablo Escobar, el patrón del mal',
#  'Pac-Man and the Ghostly Adventures',
#  'Pacific Heat',
#  'Padamu Aku Bersujud',
#  'Paprika',
#  'Paquita Salas',
#  'Paradise PD',
#  'Paranoid',
#  'Paranormal Survivor',
#  'Parks and Recreation',
#  'Part-Time Idol',
#  'Pasión de Gavilanes',
#  'Patriot Act with Hasan Minhaj',
#  "Paul Hollywood's Big Continental Road Trip",
#  'Pawn Stars',
#  'Peaky Blinders',
#  'Peasants Rebellion',
#  "Pee-wee's Playhouse",
#  'Penny Dreadful',
#  'People Just Do Nothing',
#  'Perfume',
#  'Person of Interest',
#  'Persona',
#  'Pine Gap',
#  'Pinky Malinky',
#  'Pioneers of African-American Cinema',
#  'Pioneers: First Women Filmmakers*',
#  'Planet Earth II',
#  'Planet Earth: The Complete Collection',
#  'Pocoyo',
#  'Pokémon the Series',
#  'Pokémon: Indigo League',
#  'Ponysitters Club',
#  'Popples',
#  'Pororo - The Little Penguin',
#  'Portlandia',
#  'Pose',
#  'Possessed',
#  'Powder',
#  'Power Battle Watch Car',
#  'Power Rangers Beast Morphers',
#  'Power Rangers Dino Charge',
#  'Power Rangers Dino Super Charge',
#  'Power Rangers Dino Thunder',
#  'Power Rangers Jungle Fury',
#  'Power Rangers Lightspeed Rescue',
#  'Power Rangers Lost Galaxy',
#  'Power Rangers Mystic Force',
#  'Power Rangers Ninja Steel',
#  'Power Rangers Ninja Storm',
#  'Power Rangers Operation Overdrive',
#  'Power Rangers RPM',
#  'Power Rangers S.P.D.',
#  'Power Rangers Samurai',
#  'Power Rangers Super Megaforce',
#  'Power Rangers Super Samurai',
#  'Power Rangers Time Force',
#  'Power Rangers Turbo',
#  'Power Rangers Wild Force',
#  'Power Rangers Zeo',
#  'Power Rangers in Space',
#  'Power Rangers: Megaforce',
#  'Prank Encounters',
#  'President',
#  'Pretty Man',
#  'Prince Jai Aur Dumdaar Viru',
#  'Prince of Peoria',
#  'Prison Playbook',
#  'Private Practice',
#  'Prohibition: A Film by Ken Burns and Lynn Novick',
#  'Project Mc²',
#  'Project S The Series',
#  'Psiconautas',
#  'Pucca: Love Recipe',
#  'Puella Magi Madoka Magica',
#  'Puffin Rock',
#  'Put Your Head on My Shoulder',
#  'Pyaar Tune Kya Kiya',
#  'QB1: Beyond the Lights',
#  'Qin Empire: Alliance',
#  'Quantico',
#  'Queen of No Marriage',
#  'Queen of the South',
#  'Queens of Comedy',
#  'Queens vs. Kings',
#  'Queer Eye',
#  "Queer Eye: We're in Japan!",
#  'Quicksand',
#  'Qué pena tu serie',
#  'REA(L)OVE',
#  'Rab Se Sohna Isshq',
#  'Rabbids Invasion',
#  'Rainbow Ruby',
#  'Raising Dion',
#  'Raja Rasoi Aur Anya Kahaniyan',
#  'Rake',
#  'Ramayan',
#  'Rapture',
#  'Razia Sultan',
#  'Re:Mind',
#  'Real Rob',
#  'Reality of Dream',
#  'Rebelde',
#  'Rebellion',
#  'Reboot: The Guardian Code',
#  'Record of Grancrest War',
#  'Rectify',
#  'Red vs. Blue',
#  'Refresh Man',
#  'Reggie Yates Outside Man',
#  'Regiment Diaries',
#  'Reign',
#  'Reply 1988',
#  'Reply 1994',
#  'Reply 1997',
#  'Republic of Doyle',
#  'Requiem',
#  'Residue',
#  'Resurrection: Ertugrul',
#  'Retribution',
#  'Revenge',
#  'Revisions',
#  'Revolting Rhymes',
#  'Rhythm + Flow',
#  'Rica, Famosa, Latina',
#  'Richie Rich',
#  'Rilakkuma and Kaoru',
#  'Rimba Racer',
#  'Ripper Street',
#  'Rishta.com',
#  'Rita',
#  'Riverdale',
#  'Robocar Poli',
#  'Robot Trains',
#  'Robotech',
#  'Robozuna',
#  'Roman Empire: Reign of Blood',
#  'Romance is a bonus book',
#  'Rookie Historian Goo Hae-Ryung',
#  'Roonpi Secret Love',
#  'Rosario Tijeras',
#  'Roswell, New Mexico',
#  'Rotten',
#  'Royal Pains',
#  'Rubi',
#  'Rurouni Kenshin',
#  'Russell Peters vs. the World',
#  'Russian Doll',
#  'Rust Valley Restorers',
#  'SCAMS',
#  'SWORDGAI The Animation',
#  'Sab Jholmaal Hai',
#  'Sacred Games',
#  'Sadqay Tumhare',
#  'Safe',
#  'Saint Seiya',
#  'Saint Seiya: The Lost Canvas',
#  'Salt Fat Acid Heat',
#  'Sam & Cat',
#  'Samantha!',
#  'Sammy & Co',
#  'Samurai Gourmet',
#  'Santa Clarita Diet',
#  'Satrangi',
#  'Satu Hari',
#  'Save Me',
#  'Save Our Shelter',
#  'Scandal',
#  'Scare Tactics',
#  "Schitt's Creek",
#  'Scooby-Doo!: Mystery Incorporated',
#  'Scream',
#  'Second 20s',
#  'Secret Affair',
#  'Secret City',
#  'Secret of Success',
#  'Secret of the Nile',
#  'Secrets of Great British Castles',
#  'See You in Time',
#  'Seis Manos',
#  'Selection Day',
#  'Selling Sunset',
#  'Sense8',
#  'Sensitive Skin',
#  'Serial Killer with Piers Morgan',
#  'Servant of the People',
#  'Seven Seconds',
#  'Seven and Me',
#  'Sex Education',
#  'Sex, Explained',
#  'Sexy Central',
#  'Señora Acero',
#  'Shadow',
#  'Shadow of Truth',
#  'Shaka Zulu',
#  'Shameless (U.S.)',
#  "She's Gotta Have It",
#  'She-Ra and the Princesses of Power',
#  'Sherlock',
#  'Shine On with Reese',
#  'Shooter',
#  'Shot in the Dark',
#  'Show Me the Money',
#  'Shtisel',
#  'Sick Note',
#  'Signal',
#  'Silvana Sin Lana',
#  'Silver Spoon',
#  'Simon',
#  'Sin Senos sí Hay Paraíso',
#  'Sin senos no hay paraíso',
#  'Singapore Social',
#  'Single Ladies Senior',
#  'Singles Villa',
#  'Sintonia',
#  'Sirius the Jaeger',
#  'Sisters',
#  'Skin Wars',
#  'Skin Wars: Fresh Paint',
#  'Skins',
#  'Skylanders Academy',
#  'Skylines',
#  'Slasher',
#  'Sleepless Society: Bedtime Wishes',
#  'Sleepless Society: Nyctophobia',
#  "Slobby's World",
#  'Smoking',
#  'Sofia the First',
#  'Some Assembly Required',
#  'Somebody Feed Phil',
#  'Someone Like You',
#  'Something in the Rain',
#  'Somewhere Between',
#  'Somewhere Only We Know',
#  'Sonic X',
#  'Sotus The Series',
#  'Soul Eater',
#  'Soundtrack',
#  'Space Jungle',
#  'Spark',
#  'Sparta',
#  'Spartacus',
#  'Special',
#  'Spice Up',
#  'Spinning Out',
#  'Spirit Riding Free: Pony Tales',
#  'Spirit: Riding Free',
#  'Spiritual House',
#  'Splash and Bubbles',
#  'Spotless',
#  'Spy Kids: Mission Critical',
#  'Stand Up and Away! with Brian Regan',
#  'Star Trek',
#  'Star Trek: Deep Space Nine',
#  'Star Trek: Enterprise',
#  'Star Trek: The Next Generation',
#  'Star Trek: Voyager',
#  'Star-Crossed',
#  'Station Horizon',
#  'Stay Here',
#  'Stay Tuned!',
#  'Still Game',
#  'Stoked',
#  'Stone Age',
#  'Storage Wars: Northern Treasures',
#  'Stories by Rabindranath Tagore',
#  'StoryBots Super Songs',
#  'Stranger',
#  'Stranger Things',
#  'Strawberry Shortcake: Berry Bitty Adventures',
#  'Street Food',
#  'Stretch Armstrong & the Flex Fighters',
#  'Strong',
#  'Strong Girl Bong-soon',
#  'Strongland',
#  'Stunt Science',
#  'Styling Hollywood',
#  'Suburra: Blood on Rome',
#  'Sudden',
#  'Sugar Rush',
#  'Sugar Rush Christmas',
#  'Suits',
#  "Sunderland 'Til I Die",
#  'Super Bheem',
#  'Super Drags',
#  'Super Monsters',
#  'Super Monsters Monster Party',
#  'Super Monsters Monster Pets',
#  'Super Wings',
#  'SuperNature: Wild Flyers',
#  'Supergirl',
#  'Supernatural',
#  'Surviving Escobar - Alias JJ',
#  'Surviving R. Kelly',
#  'Swami Baba Ramdev: The Untold Story',
#  'Switched',
#  'Sword Art Online',
#  'Sword Art Online Alternative: Gun Gale Online',
#  'Sym-Bionic Titan',
#  'THE UNLISTED',
#  "TURN: Washington's Spies",
#  'Tabula Rasa',
#  'Taco Chronicles',
#  'Take My Brother Away',
#  'Taken',
#  'Tales by Light',
#  'Tales of the City',
#  'Tales of the City (1993)',
#  'Talking Tom and Friends',
#  'Tango',
#  'Tayee',
#  'Tayo the Little Bus',
#  'Team Kaylie',
#  'Teasing Master Takagi-san',
#  'Teresa',
#  'Terrace House: Aloha State',
#  'Terrace House: Boys & Girls in the City',
#  'Terrace House: Opening New Doors',
#  'Terrace House: Tokyo 2019-2020',
#  'Terrorism Close Calls',
#  'Th Eena Meena Deeka Chase Comedy Show',
#  'Thackeray',
#  "That '70s Show",
#  'That Winter, the Wind Blows',
#  'The 10 Sins',
#  'The 100',
#  'The 2000s',
#  'The 43',
#  'The 4400',
#  'The A List',
#  'The Adjusters',
#  'The Adventures of Figaro Pho',
#  'The Adventures of Puss in Boots',
#  'The Adventures of Sonic the Hedgehog',
#  'The Alcàsser Murders',
#  'The Andy Griffith Show',
#  'The Apartment',
#  'The Assassination of Gianni Versace',
#  'The Bachelor',
#  'The Beat',
#  'The Beginning of Life: The Series',
#  "The Bible's Buried Secrets",
#  'The Big Catch',
#  'The Big Family Cooking Showdown',
#  'The Blacklist',
#  'The Blue Planet: A Natural History of the Oceans',
#  'The Bomb Squad',
#  'The Bonfire of Destiny',
#  'The Borgias',
#  'The Boss Baby: Back in Business',
#  'The Boulet Brothers Dragula',
#  'The Break',
#  'The Break with Michelle Wolf',
#  'The Bride of Habaek',
#  'The Calling',
#  'The Casketeers',
#  'The Cat in the Hat Knows a Lot About That!',
#  'The Chalet',
#  'The Charming Stepmom',
#  'The Chef Show',
#  "The Chefs' Line",
#  'The Chosen One',
#  'The Circle',
#  'The Club',
#  'The Code',
#  'The Comedy Lineup',
#  'The Confession Killer',
#  'The Confession Tapes',
#  'The Confrontation',
#  'The Could’ve-Gone-All-the-Way Committee',
#  'The Cravings',
#  'The Creative Indians',
#  'The Crime',
#  'The Crown',
#  'The Cuba Libre Story',
#  'The Curious Creations of Christine McConnell',
#  'The Curse of Oak Island',
#  'The Dark Crystal: Age of Resistance',
#  'The Day I Met El Chapo',
#  'The Day My Butt Went Psycho!',
#  'The Day Will Come',
#  'The Deep',
#  'The Defected',
#  'The Degenerates',
#  'The Devil Is a Part-Timer!',
#  'The Devil Next Door',
#  'The Disappearance of Madeleine McCann',
#  'The Disastrous Life of Saiki K.',
#  'The Disastrous Life of Saiki K.: Reawakened',
#  'The Dragon Prince',
#  'The Dream Catchers',
#  'The Dream Job',
#  'The Drunk and on Drugs Happy Funtime Hour',
#  "The Eagle of El-Se'eed",
#  'The Eighties',
#  'The End of the F***ing World',
#  'The Epic Tales of Captain Underpants',
#  'The Family',
#  'The Family Court',
#  'The Fear',
#  'The Fierce Wife',
#  'The Final Table',
#  'The Five',
#  'The Fix',
#  'The Flash',
#  'The Forest',
#  'The Fosters',
#  'The Frankenstein Chronicles',
#  'The Frozen Dead',
#  'The Furchester Hotel',
#  'The Future of Water',
#  'The Garfield Show',
#  'The Get Down',
#  'The Gift',
#  'The Golden Path',
#  'The Golden Years with Javed Akhtar',
#  'The Good Bandit',
#  'The Good Cop',
#  'The Good Place',
#  'The Great British Baking Show',
#  'The Great British Baking Show: Holidays',
#  'The Great British Baking Show: Masterclass',
#  'The Great British Baking Show: The Beginnings',
#  'The Great Train Robbery',
#  'The Guild',
#  'The Hateful Eight: Extended Version',
#  'The Haunting of Hill House',
#  'The Healing Powers of Dude',
#  'The Hockey Girls',
#  'The Hollow',
#  'The Hollywood Masters',
#  'The Homecoming',
#  'The Honeymoon Stand Up Special',
#  'The Hook Up Plan',
#  'The House That Made Me',
#  'The House of Flowers',
#  'The Hunt',
#  'The I-Land',
#  'The IT Crowd',
#  'The In-Laws',
#  'The InBESTigators',
#  'The Inbetweeners',
#  'The Indian Detective',
#  'The Inmate',
#  'The Innocent Man',
#  'The Innocents',
#  'The Investigator: A British Crime Story',
#  'The Irish Mob',
#  'The Iron Lady',
#  'The Irregular at Magic High School',
#  'The Jaime Maussan Show',
#  'The Joel McHale Show with Joel McHale',
#  'The Judgement',
#  'The Jungle Book',
#  'The K2',
#  'The Keepers',
#  'The Kindness Diaries',
#  "The King's Avatar",
#  'The Kirlian Frequency',
#  'The Kominsky Method',
#  'The L Word',
#  'The Lady in Dignity',
#  'The Land of Hypocrisy',
#  'The Last Czars',
#  'The Last Kids on Earth',
#  'The Last Kingdom',
#  'The Last O.G.',
#  'The Last of the Schmucks',
#  'The Legend of Bruce Lee',
#  'The Legend of White Snake',
#  'The Letdown',
#  'The Liar',
#  'The Liar and His Lover',
#  'The Lies Within',
#  'The Little Nyonya',
#  'The Lizzie Borden Chronicles',
#  'The Magic School Bus',
#  'The Magic School Bus Rides Again',
#  'The Magicians',
#  'The Making of Frozen Planet',
#  'The Many Faces of Ito',
#  'The Mechanism',
#  'The Messengers',
#  'The Method',
#  'The Mind of a Chef',
#  'The Mind, Explained',
#  'The Minimighty Kids',
#  'The Ministry of Time',
#  'The Miracle',
#  'The Missing Menu',
#  'The Mist',
#  'The Mortified Guide',
#  'The Most Beautiful Hands of Delhi',
#  'The Movies That Made Us',
#  'The Mr. Peabody and Sherman Show',
#  'The Murder Detectives',
#  'The Naked Director',
#  'The Neighbor',
#  'The New Legends of Monkey',
#  'The Night Shift',
#  'The Nineties',
#  'The OA',
#  'The Oath',
#  'The Office (U.S.)',
#  'The Order',
#  'The Originals',
#  'The Outsiders',
#  'The Paper',
#  'The Perfect Match',
#  'The Politician',
#  'The Prince Who Turns into a Frog',
#  'The Prince of Tennis ~ Match! Tennis Juniors ~',
#  'The Princess Weiyoung',
#  'The Protector',
#  'The Pyramid Code',
#  'The Queen of Flow',
#  'The Rain',
#  'The Ranch',
#  'The Rap Game',
#  'The Real Football Factories',
#  'The Repair Shop',
#  'The Returned',
#  'The Rise of Phoenixes',
#  'The Road to Calvary',
#  'The Road to Love',
#  'The Royal House of Windsor',
#  'The Seven Deadly Sins',
#  'The Seventies',
#  'The Shannara Chronicles',
#  'The Sinner',
#  'The Sniffer',
#  'The Society',
#  'The Sound of Your Heart',
#  'The Sound of Your Heart: Reboot',
#  'The Spy',
#  'The Staircase',
#  'The Standups',
#  'The Story of God with Morgan Freeman',
#  'The Story of Us with Morgan Freeman',
#  'The Stranded',
#  'The Super Mario Bros. Super Show!',
#  'The Terminal',
#  'The Toys That Made Us',
#  'The Traffickers',
#  'The Truth',
#  'The Truth Seekers',
#  'The Tudors',
#  'The Twilight Zone (Original Series)',
#  'The Ultimatum',
#  'The Umbrella Academy',
#  'The Underwear',
#  'The Universe',
#  'The Untamed',
#  'The Vampire Diaries',
#  'The Vietnam War: A Film by Ken Burns and Lynn Novick',
#  'The Walking Dead',
#  'The War: A Film by Ken Burns and Lynn Novick',
#  'The West Wing',
#  'The Who Was? Show',
#  'The Windsors',
#  'The Witcher',
#  'The Womanizer',
#  "The World's Most Extraordinary Homes",
#  'The Worst Witch',
#  'The Writer',
#  'The Yard',
#  'The Year of Happiness and Love',
#  'Thieves of the Wood',
#  'ThirTEEN Terrors',
#  'This Evening',
#  'This Is My Love',
#  'Three Days of Christmas',
#  'Three Wives One Husband',
#  'Tidelands',
#  'Tidying Up with Marie Kondo',
#  'Tiempos de guerra',
#  'Tientsin Mystic',
#  'Tiffany Haddish Presents: They Ready',
#  'Tijuana',
#  'Til Death Do Us Part',
#  'Time: The Kalief Browder Story',
#  'Timeless Season',
#  'Timeline',
#  'Tiny House Nation',
#  'Tip the Mouse',
#  'Titipo Titipo',
#  'Toast of London',
#  'Tobot',
#  'Together',
#  'Tokyo Trial',
#  'Tomorrow with You',
#  'Tong: Memories',
#  'Toon',
#  'Top 10 Secrets and Mysteries',
#  'Top Boy',
#  'Top Grier',
#  'Total Drama',
#  'Towies',
#  'Trailer Park Boys',
#  'Trailer Park Boys: Out of the Park: Europe',
#  'Trailer Park Boys: Out of the Park: USA',
#  'Trailer Park Boys: The Animated Series',
#  'Traitors',
#  'Transfers',
#  'Transformers Prime',
#  'Transformers Rescue Bots Academy',
#  'Transformers: Cyberverse',
#  'Transformers: Rescue Bots',
#  'Transformers: Robots in Disguise',
#  'Travelers',
#  'Treehouse Detectives',
#  'Triad Princess',
#  'Trigger Warning with Killer Mike',
#  'Trinkets',
#  'Trio and a Bed',
#  'Trollhunters',
#  'Trolls: The Beat Goes On!',
#  'Trotsky',
#  'Troy',
#  'True Tunes',
#  'True and the Rainbow Kingdom',
#  'True: Magical Friends',
#  'True: Wonderful Wishes',
#  'Trump: An American Dream',
#  'Tuca & Bertie',
#  'Tundukkan Playboy Itu',
#  'Tunnel',
#  'Turbo FAST',
#  'Turn Up Charlie',
#  'Twelve Forever',
#  'Twice Upon A Time',
#  'Twin Peaks',
#  'Two Fathers',
#  'Two Sentence Horror Stories',
#  'Typewriter',
#  'Ugly Delicious',
#  'Ugly Duckling',
#  'Ultimate Beastmaster',
#  'Ultimate Beastmaster México',
#  'Ultraman',
#  'Ultramarine Magmell',
#  'Ultraviolet',
#  'Unauthorized Living',
#  'Unbelievable',
#  'Unbreakable Kimmy Schmidt',
#  'Unchained Fate',
#  'Under Arrest',
#  'Under the Black Moonlight',
#  'Undercover',
#  'Undercover Law',
#  'Unit 42',
#  'Unnatural Selection',
#  'Unrequited Love',
#  'Unriddle',
#  'Unsolved',
#  'Until Dawn',
#  'Upin & Ipin',
#  'V Wars',
#  'V.R. Troopers',
#  'Vagabond',
#  'Vai Anitta',
#  'Valor',
#  'Vampire Knight',
#  'Van Helsing',
#  'VeggieTales in the City',
#  'VeggieTales in the House',
#  'Velvet',
#  'Velvet Colección',
#  'Versailles',
#  'Vexed',
#  'ViR: The Robot Boy',
#  'Victim Number 8',
#  'Victorious',
#  'Vientos de agua',
#  'Violet Evergarden',
#  'Violet Evergarden: Special',
#  'Virgin River',
#  'Voice',
#  'Voltron: Legendary Defender',
#  'Vroomiz',
#  'W/ Bob & David',
#  'W1A',
#  'WHAT / IF',
#  'Wadi',
#  'Wait, My Youth',
#  'Wake Up',
#  'Wakfu',
#  'Wakfu: The Quest for the Six Eliatrope Dofus',
#  'Wanderlust',
#  'Wanted',
#  'Warrior',
#  'Wartime Portraits',
#  'Watership Down',
#  'Way Back into Love',
#  'We Are the Wave',
#  'We Bare Bears',
#  'We Speak Dance',
#  "We're Lalaloopsy",
#  'Weeds',
#  'Weird Wonders of the World',
#  'Welcome to the Family',
#  'Well-Intended Love',
#  'Wentworth',
#  'West Coast Customs',
#  'Westside',
#  'Westside Story',
#  'Wet Hot American Summer',
#  'Wet Hot American Summer: Ten Years Later',
#  'What Happens to My Family',
#  'What If?',
#  'What Is Love?',
#  'What She Put on the Table',
#  'What in the World Happened?',
#  "What's New Scooby-Doo?",
#  'When Calls the Heart',
#  'When Heroes Fly',
#  'When I See You Again',
#  'When They See Us',
#  'When the Camellia Blooms',
#  'White Gold',
#  'White Nights',
#  'White Rabbit Project',
#  'Who Killed Little Gregory?',
#  "Who's the One",
#  'Wild Alaska',
#  'Wild Arabia',
#  'Wild District',
#  'Wild Wild Country',
#  'Winsanity',
#  'Winter Sun',
#  'Witches: A Century of Murder',
#  'Wolf',
#  'Women Behind Bars',
#  'Word Party',
#  "Workin' Moms",
#  'World War II in Colour',
#  'World at Your Feet',
#  'World of Winx',
#  "World's Busiest Cities",
#  'Wormwood',
#  'Wu Assassins',
#  'Wynonna Earp',
#  'YG Future Strategy Office',
#  'YOM',
#  'Yankee',
#  'Yanxi Palace: Princess Adventures',
#  'Yeh Meri Family',
#  'Yes We Can!',
#  'Yo-Kai Watch',
#  'Yoko',
#  'YooHoo to the Rescue',
#  'You',
#  'You vs. Wild',
#  "You're My Destiny",
#  'Young & Hungry',
#  'Your lie in April',
#  'Yours Fatefully',
#  'Yu-Gi-Oh!',
#  'Yu-Gi-Oh! Arc-V',
#  'Yummy Mummies',
#  'Yunus Emre',
#  'Z Nation',
#  'Z4',
#  'Zak Storm',
#  'Zig & Sharko',
#  'Zindagi Gulzar Hai',
#  'Zombie Dumb',
#  'Zona Rosa',
#  'Zoo',
#  "Zumbo's Just Desserts",
#  'Şubat',
#  'แผนร้ายนายเจ้าเล่ห์',
#  '\u200bSAINT SEIYA: Knights of the Zodiac',
#  '忍者ハットリくん',
#  '海的儿子',
#  '마녀사냥']

# %%
import pickle
model_save_path = "model.pkl"
with open(model_save_path,'wb') as file:
    pickle.dump(recommendations,file)

# %%
#unpickle model
model_load_path = "xgb_model.pkl"
with open(model_load_path,'rb') as file:
    unpickled_model_xgb = pickle.load(file)
